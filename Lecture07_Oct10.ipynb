# %% [markdown]
# <a href="https://colab.research.google.com/github/apraveen005/machine_learning_with_python/blob/master/Lecture07_Oct10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#     Unnamed: 0        date  department  ...  type  unemployment  weekly_sales
# 0            0  2010-02-05           1  ...     A         8.106      24924.50
# 1            1  2010-03-05           1  ...     A         8.106      21827.90
# 2            2  2010-04-02           1  ...     A         7.808      57258.43
# 3            3  2010-05-07           1  ...     A         7.808      17413.94
# 4            4  2010-06-04           1  ...     A         7.808      17558.09
# 5            5  2010-07-02           1  ...     A         7.787      16333.14
# 6            6  2010-08-06           1  ...     A         7.787      17508.41
# 7            7  2010-09-03           1  ...     A         7.787      16241.78
# 8            8  2010-10-01           1  ...     A         7.838      20094.19
# 9            9  2010-11-05           1  ...     A         7.838      34238.88
# 10          10  2010-12-03           1  ...     A         7.838      22517.56
# ...

# %%
import numpy as np

# %%
sales.groupby('department')[['unemployment','weekly_sales']].agg([np.mean,np.median])
# Out:
#            unemployment         weekly_sales
#                    mean median          mean     median
# department
# 1              7.854417  7.808  23491.755000  18826.140
# 2              7.854417  7.808  47421.124167  47676.755
# 3              7.854417  7.808  12872.590000  11006.965
# 4              7.854417  7.808  38382.255833  38033.370
# 5              8.106000  8.106  27655.760000  27655.760

# %%
#pivot table
sales
# Out:
#     Unnamed: 0        date  department  ...  type  unemployment  weekly_sales
# 0            0  2010-02-05           1  ...     A         8.106      24924.50
# 1            1  2010-03-05           1  ...     A         8.106      21827.90
# 2            2  2010-04-02           1  ...     A         7.808      57258.43
# 3            3  2010-05-07           1  ...     A         7.808      17413.94
# 4            4  2010-06-04           1  ...     A         7.808      17558.09
# 5            5  2010-07-02           1  ...     A         7.787      16333.14
# 6            6  2010-08-06           1  ...     A         7.787      17508.41
# 7            7  2010-09-03           1  ...     A         7.787      16241.78
# 8            8  2010-10-01           1  ...     A         7.838      20094.19
# 9            9  2010-11-05           1  ...     A         7.838      34238.88
# 10          10  2010-12-03           1  ...     A         7.838      22517.56
# ...

# %%
sales.pivot_table(index='department',values='weekly_sales')
# Out:
#             weekly_sales
# department
# 1           23491.755000
# 2           47421.124167
# 3           12872.590000
# 4           38382.255833
# 5           27655.760000

# %%
sales.pivot_table(index='department',values=['weekly_sales','unemployment'],aggfunc=[np.mean,np.median])
# Out:
#                    mean                     median
#            unemployment  weekly_sales unemployment weekly_sales
# department
# 1              7.854417  23491.755000        7.808    18826.140
# 2              7.854417  47421.124167        7.808    47676.755
# 3              7.854417  12872.590000        7.808    11006.965
# 4              7.854417  38382.255833        7.808    38033.370
# 5              8.106000  27655.760000        8.106    27655.760

# %%
sales
# Out:
# 'department'

# %%
sales=pd.read_csv('sales.csv')

# %%
sales
# Out:
#     Unnamed: 0        date  department  ...  type  unemployment  weekly_sales
# 0            0  2010-02-05           1  ...     A         8.106      24924.50
# 1            1  2010-03-05           1  ...     A         8.106      21827.90
# 2            2  2010-04-02           1  ...     A         7.808      57258.43
# 3            3  2010-05-07           1  ...     A         7.808      17413.94
# 4            4  2010-06-04           1  ...     A         7.808      17558.09
# 5            5  2010-07-02           1  ...     A         7.787      16333.14
# 6            6  2010-08-06           1  ...     A         7.787      17508.41
# 7            7  2010-09-03           1  ...     A         7.787      16241.78
# 8            8  2010-10-01           1  ...     A         7.838      20094.19
# 9            9  2010-11-05           1  ...     A         7.838      34238.88
# 10          10  2010-12-03           1  ...     A         7.838      22517.56
# ...

# %%
sales=sales.set_index('department')

# %%
sales
# Out:
#             Unnamed: 0        date  ...  unemployment  weekly_sales
# department                          ...
# 1                    0  2010-02-05  ...         8.106      24924.50
# 1                    1  2010-03-05  ...         8.106      21827.90
# 1                    2  2010-04-02  ...         7.808      57258.43
# 1                    3  2010-05-07  ...         7.808      17413.94
# 1                    4  2010-06-04  ...         7.808      17558.09
# 1                    5  2010-07-02  ...         7.787      16333.14
# 1                    6  2010-08-06  ...         7.787      17508.41
# 1                    7  2010-09-03  ...         7.787      16241.78
# 1                    8  2010-10-01  ...         7.838      20094.19
# 1                    9  2010-11-05  ...         7.838      34238.88
# 1                   10  2010-12-03  ...         7.838      22517.56
# 1                   11  2011-01-07  ...         7.742      15984.24
# ...

# %%
sales=sales.reset_index()

# %%
sales
# Out:
#     department  Unnamed: 0        date  ...  type  unemployment  weekly_sales
# 0            1           0  2010-02-05  ...     A         8.106      24924.50
# 1            1           1  2010-03-05  ...     A         8.106      21827.90
# 2            1           2  2010-04-02  ...     A         7.808      57258.43
# 3            1           3  2010-05-07  ...     A         7.808      17413.94
# 4            1           4  2010-06-04  ...     A         7.808      17558.09
# 5            1           5  2010-07-02  ...     A         7.787      16333.14
# 6            1           6  2010-08-06  ...     A         7.787      17508.41
# 7            1           7  2010-09-03  ...     A         7.787      16241.78
# 8            1           8  2010-10-01  ...     A         7.838      20094.19
# 9            1           9  2010-11-05  ...     A         7.838      34238.88
# 10           1          10  2010-12-03  ...     A         7.838      22517.56
# ...

# %%
sales=sales.reset_index(drop=True)

# %%
sales
# Out:
#     department  Unnamed: 0        date  ...  type  unemployment  weekly_sales
# 0            1           0  2010-02-05  ...     A         8.106      24924.50
# 1            1           1  2010-03-05  ...     A         8.106      21827.90
# 2            1           2  2010-04-02  ...     A         7.808      57258.43
# 3            1           3  2010-05-07  ...     A         7.808      17413.94
# 4            1           4  2010-06-04  ...     A         7.808      17558.09
# 5            1           5  2010-07-02  ...     A         7.787      16333.14
# 6            1           6  2010-08-06  ...     A         7.787      17508.41
# 7            1           7  2010-09-03  ...     A         7.787      16241.78
# 8            1           8  2010-10-01  ...     A         7.838      20094.19
# 9            1           9  2010-11-05  ...     A         7.838      34238.88
# 10           1          10  2010-12-03  ...     A         7.838      22517.56
# ...

# %%
import pandas as pd
sales=pd.read_csv('sales.csv')
sales
# Out:
#     Unnamed: 0        date  department  ...  type  unemployment  weekly_sales
# 0            0  2010-02-05           1  ...     A         8.106      24924.50
# 1            1  2010-03-05           1  ...     A         8.106      21827.90
# 2            2  2010-04-02           1  ...     A         7.808      57258.43
# 3            3  2010-05-07           1  ...     A         7.808      17413.94
# 4            4  2010-06-04           1  ...     A         7.808      17558.09
# 5            5  2010-07-02           1  ...     A         7.787      16333.14
# 6            6  2010-08-06           1  ...     A         7.787      17508.41
# 7            7  2010-09-03           1  ...     A         7.787      16241.78
# 8            8  2010-10-01           1  ...     A         7.838      20094.19
# 9            9  2010-11-05           1  ...     A         7.838      34238.88
# 10          10  2010-12-03           1  ...     A         7.838      22517.56
# ...

# %%
sales['department',].value_counts()
# Out:
# 4    12
# 3    12
# 2    12
# 1    12
# 5     2
# Name: department, dtype: int64

# %%
mpg=pd.read_csv('auto-mpg.csv')
mpg
# Out:
#       mpg  displ   hp  weight  accel  origin  size
# 0    18.0  250.0   88    3139   14.5      US  15.0
# 1     9.0  304.0  193    4732   18.5      US  20.0
# 2    36.1   91.0   60    1800   16.4    Asia  10.0
# 3    18.5  250.0   98    3525   19.0      US  15.0
# 4    34.3   97.0   78    2188   15.8  Europe  10.0
# ..    ...    ...  ...     ...    ...     ...   ...
# 387  18.0  250.0   88    3021   16.5      US  15.0
# 388  27.0  151.0   90    2950   17.3      US  10.0
# 389  29.5   98.0   68    2135   16.6    Asia  10.0
# 390  17.5  250.0  110    3520   16.4      US  15.0
# 391  25.1  140.0   88    2720   15.4      US  10.0
#
# [392 rows x 7 columns]

# %%
mpg.set_index('origin')
# Out:
#          mpg  displ   hp  weight  accel  size
# origin
# US      18.0  250.0   88    3139   14.5  15.0
# US       9.0  304.0  193    4732   18.5  20.0
# Asia    36.1   91.0   60    1800   16.4  10.0
# US      18.5  250.0   98    3525   19.0  15.0
# Europe  34.3   97.0   78    2188   15.8  10.0
# ...      ...    ...  ...     ...    ...   ...
# US      18.0  250.0   88    3021   16.5  15.0
# US      27.0  151.0   90    2950   17.3  10.0
# Asia    29.5   98.0   68    2135   16.6  10.0
# US      17.5  250.0  110    3520   16.4  15.0
# US      25.1  140.0   88    2720   15.4  10.0
#
# [392 rows x 6 columns]

# %%
mpg['origin'].value_counts()
# Out:
# US        245
# Asia       79
# Europe     68
# Name: origin, dtype: int64

# %%
mpg=mpg.sort_values('origin')
mpg
# Out:
#       mpg  displ   hp  weight  accel origin  size
# 203  34.0  108.0   70    2245   16.9   Asia  10.0
# 5    32.9  119.0  100    2615   14.8   Asia  10.0
# 6    32.2  108.0   75    2265   15.2   Asia  10.0
# 241  40.8   85.0   65    2110   19.2   Asia  10.0
# 385  20.0  156.0  122    2807   13.5   Asia  15.0
# ..    ...    ...  ...     ...    ...    ...   ...
# 331  14.0  351.0  153    4129   13.0     US  20.0
# 332  17.0  305.0  130    3840   15.4     US  20.0
# 333  16.0  400.0  170    4668   11.5     US  20.0
# 336  27.0  151.0   90    2735   18.0     US  10.0
# 391  25.1  140.0   88    2720   15.4     US  10.0
#
# [392 rows x 7 columns]

# %%
mpg=mpg.set_index(['origin','size'])
mpg
# Out:
#               mpg  displ   hp  weight  accel
# origin size
# Asia   10.0  34.0  108.0   70    2245   16.9
#        10.0  32.9  119.0  100    2615   14.8
#        10.0  32.2  108.0   75    2265   15.2
#        10.0  40.8   85.0   65    2110   19.2
#        15.0  20.0  156.0  122    2807   13.5
# ...           ...    ...  ...     ...    ...
# US     20.0  14.0  351.0  153    4129   13.0
#        20.0  17.0  305.0  130    3840   15.4
#        20.0  16.0  400.0  170    4668   11.5
#        10.0  27.0  151.0   90    2735   18.0
#        10.0  25.1  140.0   88    2720   15.4
#
# [392 rows x 5 columns]

# %%
mpg.loc[['Asia','Europe']]
# Out:
#               mpg  displ   hp  weight  accel
# origin size
# Asia   10.0  34.0  108.0   70    2245   16.9
#        10.0  32.9  119.0  100    2615   14.8
#        10.0  32.2  108.0   75    2265   15.2
#        10.0  40.8   85.0   65    2110   19.2
#        15.0  20.0  156.0  122    2807   13.5
# ...           ...    ...  ...     ...    ...
# Europe 10.0  41.5   98.0   76    2144   14.7
#        10.0  21.0  120.0   87    2979   19.5
#        10.0  43.1   90.0   48    1985   21.5
#        10.0  25.0  121.0  115    2671   13.5
#        10.0  30.5   97.0   78    2190   14.1
#
# [147 rows x 5 columns]

# %%
mpg
# Out:
#               mpg  displ   hp  weight  accel
# origin size
# Asia   10.0  34.0  108.0   70    2245   16.9
#        10.0  32.9  119.0  100    2615   14.8
#        10.0  32.2  108.0   75    2265   15.2
#        10.0  40.8   85.0   65    2110   19.2
#        15.0  20.0  156.0  122    2807   13.5
# ...           ...    ...  ...     ...    ...
# US     20.0  14.0  351.0  153    4129   13.0
#        20.0  17.0  305.0  130    3840   15.4
#        20.0  16.0  400.0  170    4668   11.5
#        10.0  27.0  151.0   90    2735   18.0
#        10.0  25.1  140.0   88    2720   15.4
#
# [392 rows x 5 columns]

# %%
sales
# Out:
#     Unnamed: 0        date  department  ...  type  unemployment  weekly_sales
# 0            0  2010-02-05           1  ...     A         8.106      24924.50
# 1            1  2010-03-05           1  ...     A         8.106      21827.90
# 2            2  2010-04-02           1  ...     A         7.808      57258.43
# 3            3  2010-05-07           1  ...     A         7.808      17413.94
# 4            4  2010-06-04           1  ...     A         7.808      17558.09
# 5            5  2010-07-02           1  ...     A         7.787      16333.14
# 6            6  2010-08-06           1  ...     A         7.787      17508.41
# 7            7  2010-09-03           1  ...     A         7.787      16241.78
# 8            8  2010-10-01           1  ...     A         7.838      20094.19
# 9            9  2010-11-05           1  ...     A         7.838      34238.88
# 10          10  2010-12-03           1  ...     A         7.838      22517.56
# ...

# %%
import matplotlib.pyplot as plt
sales.plot().hist()
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e731ebcfde68> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 sales.plot().hist()
#       3 plt.show
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: hist() missing 1 required positional argument: 'x'
