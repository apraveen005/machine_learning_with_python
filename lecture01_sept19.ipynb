# %% [markdown]
# <a href="https://colab.research.google.com/github/apraveen005/python_notes/blob/master/lecture01_sept19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Lecture 01
#Introduction of Data Science
#variabe declaration with datatypes.
name='praveen'
age=25
height=5.9
char=True
print(type(name))
print(type(age))
print(type(height))
print(type(char))
type(name)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# str

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.style.use('dark_background')

fig, ax = plt.subplots()

L = 6
x = np.linspace(2, L)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(1, L, ncolors, endpoint=True)
for s in shift:
    ax.plot(x, np.sin(x + s), 'o-')
ax.set_xlabel('Age')
ax.set_ylabel('Height')
ax.set_title("'dark_background' style sheet")

plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %%
fam=('ram',20,'john',30,'charlie',40)
type(fam)
# Out:
# tuple

# %%
fam[2]
# Out:
# 'john'
